# %%
from pyspark.sql import SparkSession

spark = SparkSession\
    .builder\
    .appName("Pyspark Practice")\
    .getOrCreate()

spark

# %%
df = spark.read.table("ecommerce_analytics.data_warehouse.fact_orders_item")
