-- %% [markdown]
-- ## Create Table

-- %%
CREATE TABLE batch_1.practice.customers (
    customer_id INT,
    name VARCHAR(50),
    country VARCHAR(50),
    signup_date DATE
    
    
);

-- %%
select * from batch_1.star_schema.customers
